# %% [markdown]
# ### Assignment 01
# Linear regression by using Deep Neural network: Implement Boston housing price prediction problem by Linear regression using Deep Neural network. Use Boston House price prediction dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_3530/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# Loads the dataset from Google Drive using pandas.
df = pd.read_csv('/content/sample_data/BostonHousing.csv')

df.head()
# Out:
#    Crime_rate    zn  indus  chas    nox     rm   Age  Distance  rad  tax  \
# 0     0.00632  18.0   2.31     0  0.538  6.575  65.2    4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421  78.9    4.9671    2  242
# 2     0.02729   0.0   7.07     0  0.469  7.185  61.1    4.9671    2  242
# 3     0.03237   0.0   2.18     0  0.458  6.998  45.8    6.0622    3  222
# 4     0.06905   0.0   2.18     0  0.458  7.147  54.2    6.0622    3  222
#
#    ptratio       b  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.isnull().sum()
# Out:
# Crime_rate    0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            5
# Age           0
# Distance      0
# rad           0
# tax           0
# ptratio       0
# b             0
# lstat         0
# medv          0
# dtype: int64

# %%
# Fills missing values in the 'rm' column with the mean of that column.

df['rm'].fillna(df['rm'].mean(), inplace=True)

df.isnull().sum()
# Out:
# /tmp/ipykernel_3530/2618865816.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rm'].fillna(df['rm'].mean(), inplace=True)
# Crime_rate    0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# Age           0
# Distance      0
# rad           0
# tax           0
# ptratio       0
# b             0
# lstat         0
# medv          0
# dtype: int64

# %%
# Splits the dataset into: `x`: Features  `y`: Target variable
x = df.drop('medv', axis=1)
y=df['medv']

# %%
# Splits data into training and testing sets for model training and evaluation.

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
# Scale the feature values between 0 and 1 using MinMaxScaler, Prevents domination
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Create a neural network with:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()

model.add(Dense(128, activation='relu'))      # One hidden layer (Dense(128) with ReLU activation).
model.add(Dense(1, activation='linear'))      # One output layer with a linear activation (for regression).

# Compiles the model
model.compile(loss='mae', optimizer='adam', metrics=['mse', 'mae'])

# %%
# Trains the model on the training data for 50 epochs

model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 22.3150 - mae: 22.3150 - mse: 585.9853
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.6776 - mae: 21.6776 - mse: 559.6484
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.9294 - mae: 20.9294 - mse: 528.9998
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.9789 - mae: 19.9789 - mse: 492.4792
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.7830 - mae: 18.7830 - mse: 447.6802
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.3417 - mae: 17.3417 - mse: 397.9559
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.7360 - mae: 15.7360 - mse: 345.2214
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.0438 - mae: 14.0438 - mse: 291.9847
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.4740 - mae: 12.4740 - mse: 243.5158
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.1565 - mae: 11.1565 - mse: 203.2680
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.1890 - mae: 10.1890 - mse: 174.1762
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4913 - mae: 9.4913 - mse: 152.5026
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0366 - mae: 9.0366 - mse: 139.0661
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6365 - mae: 8.6365 - mse: 128.5377
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3429 - mae: 8.3429 - mse: 120.6727
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0672 - mae: 8.0672 - mse: 114.0476
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8180 - mae: 7.8180 - mse: 108.7689
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5725 - mae: 7.5725 - mse: 103.8950
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3260 - mae: 7.3260 - mse: 99.1279
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0959 - mae: 7.0959 - mse: 94.5792
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8632 - mae: 6.8632 - mse: 90.3293
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6163 - mae: 6.6163 - mse: 85.8294
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4126 - mae: 6.4126 - mse: 82.2157
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2166 - mae: 6.2166 - mse: 78.2169
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0237 - mae: 6.0237 - mse: 74.5099
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8486 - mae: 5.8486 - mse: 71.8646
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6775 - mae: 5.6775 - mse: 69.0622
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5218 - mae: 5.5218 - mse: 66.4817
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3967 - mae: 5.3967 - mse: 64.1084
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2888 - mae: 5.2888 - mse: 62.5806
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2114 - mae: 5.2114 - mse: 61.0320
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1489 - mae: 5.1489 - mse: 59.6024
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0931 - mae: 5.0931 - mse: 58.3546
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0459 - mae: 5.0459 - mse: 57.3659
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9989 - mae: 4.9989 - mse: 56.3895
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9605 - mae: 4.9605 - mse: 55.3639
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9120 - mae: 4.9120 - mse: 54.5270
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8820 - mae: 4.8820 - mse: 54.5661
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8346 - mae: 4.8346 - mse: 53.2456
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7901 - mae: 4.7901 - mse: 52.2885
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7498 - mae: 4.7498 - mse: 51.6386
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7111 - mae: 4.7111 - mse: 50.9196
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6746 - mae: 4.6746 - mse: 50.5126
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6274 - mae: 4.6274 - mse: 49.6726
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5894 - mae: 4.5894 - mse: 48.8735
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5802 - mae: 4.5802 - mse: 48.9524
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5142 - mae: 4.5142 - mse: 47.0829
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4740 - mae: 4.4740 - mse: 46.4061
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4349 - mae: 4.4349 - mse: 46.2851
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4005 - mae: 4.4005 - mse: 45.3833

# %%
# Evaluates the model’s performance on the test data
metrics = model.evaluate(x_test, y_test)
metrics
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 21.6631 - mae: 21.6631 - mse: 549.3882
# [21.663097381591797, 549.38818359375, 21.663097381591797]

# %%
# Use the trained model to make predictions on the test data
y_pred = model.predict(x_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
# Reshapes the actual target values for comparison with predictions (makes it a 2D array)
y_test = np.array(y_test).reshape(-1, 1)

# %%
# Plots the actual vs predicted values of medv.
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
